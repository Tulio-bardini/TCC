# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/TS_ALUNO_34EM.csv", sep=";")

# %%
# Abrindo infos dos questionários dos estudantes
arquivo_excel = 'data/infos_questoes_questionarios_EM.csv'
df_infos_questions = pd.read_csv(arquivo_excel)
df_infos_questions.drop_duplicates(inplace=True)

# Abrindo infos das alternativas dos questionários
arquivo_excel = 'data/infos_alternativas_questionarios_EM.csv'
df_infos_alternatives = pd.read_csv(arquivo_excel)
df_infos_alternatives.drop_duplicates(inplace=True)

# %%
columns_questions = ['TX_RESP_Q01', 'TX_RESP_Q02', 'TX_RESP_Q03', 'TX_RESP_Q04', 'TX_RESP_Q05', 'TX_RESP_Q06a', 'TX_RESP_Q06b', 'TX_RESP_Q06c', 'TX_RESP_Q06d', 'TX_RESP_Q06e', 
                    'TX_RESP_Q07', 'TX_RESP_Q08', 'TX_RESP_Q09a', 'TX_RESP_Q09b', 'TX_RESP_Q09c', 'TX_RESP_Q09d', 'TX_RESP_Q09e', 'TX_RESP_Q09f', 'TX_RESP_Q10a', 'TX_RESP_Q10b',
                    'TX_RESP_Q10c', 'TX_RESP_Q11a', 'TX_RESP_Q11b', 'TX_RESP_Q11c', 'TX_RESP_Q11d', 'TX_RESP_Q11e', 'TX_RESP_Q11f', 'TX_RESP_Q11g', 'TX_RESP_Q11h', 'TX_RESP_Q12a',
                    'TX_RESP_Q12b', 'TX_RESP_Q12c', 'TX_RESP_Q12d', 'TX_RESP_Q12e', 'TX_RESP_Q12f', 'TX_RESP_Q12g', 'TX_RESP_Q12h', 'TX_RESP_Q12i', 'TX_RESP_Q13', 'TX_RESP_Q14', 
                    'TX_RESP_Q15', 'TX_RESP_Q16', 'TX_RESP_Q17', 'TX_RESP_Q18', 'TX_RESP_Q19', 'TX_RESP_Q20a', 'TX_RESP_Q20b', 'TX_RESP_Q20c', 'TX_RESP_Q20d', 'TX_RESP_Q20e', 
                    'TX_RESP_Q21', 'TX_RESP_Q22', 'TX_RESP_Q23a', 'TX_RESP_Q23b', 'TX_RESP_Q23c', 'TX_RESP_Q23d', 'TX_RESP_Q23e', 'TX_RESP_Q23f', 'TX_RESP_Q23g', 'TX_RESP_Q23h', 
                    'TX_RESP_Q23i']

# %%
for i, col in enumerate(columns_questions):
    
    question = df_infos_questions[df_infos_questions['Variável'] == col]['Descrição (texto da pergunta)']
    alternatives = df_infos_alternatives[df_infos_alternatives['Variável'] == col]

    print(question[i])
    for index, row in alternatives.iterrows():
        print(f'{row['Código da opção de resposta']} - {row['Texto da opção de resposta']}')

    sb.histplot(df[col])
    plt.show()
# Out:
# Qual é o seu sexo?
# * - Nulo
# . - Branco
# A - Masculino.
# B - Feminino.
# Qual é a sua idade?
# * - Nulo
# . - Branco
# A - 16 anos ou menos.
# B - 17 anos.
# C - 18 anos.
# D - 19 anos.
# E - 20 anos.
# F - 21 anos ou mais.
# Qual língua que seus pais falam com mais frequência em casa?
# * - Nulo
# . - Branco
# A - Português.
# B - Espanhol.
# C - Outra língua.
# Qual é a sua cor ou raça?
# * - Nulo
# . - Branco
# A - Branca.
# B - Preta.
# C - Parda.
# D - Amarela.
# E - Indígena.
# F - Não quero declarar.
# Você possui algum tipo de necessidade especial?
# * - Nulo
# . - Branco
# A - Sim.
# B - Não.
# Normalmente quem mora na sua casa? - Mãe ou madrasta.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Normalmente quem mora na sua casa? - Pai ou padrasto.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Normalmente quem mora na sua casa? - Irmão(s) ou irmã(s).
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Normalmente quem mora na sua casa? - Avô ou avó.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Normalmente quem mora na sua casa? - Outros (tios primos etc.).
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Qual é a maior escolaridade da sua mãe (ou mulher responsável por você)?
# * - Nulo
# . - Branco
# A - Não completou o 5º ano do Ensino Fundamental.
# B - Ensino Fundamental, até o 5º ano.
# C - Ensino Fundamental completo.
# D - Ensino Médio completo.
# E - Ensino Superior completo (faculdade ou graduação).
# F - Não sei.
# Qual é a maior escolaridade de seu pai (ou homem responsável por você)?
# * - Nulo
# . - Branco
# A - Não completou o 5º ano do Ensino Fundamental.
# B - Ensino Fundamental, até o 5º ano.
# C - Ensino Fundamental completo.
# D - Ensino Médio completo.
# E - Ensino Superior completo (faculdade ou graduação).
# F - Não sei.
# Com que frequência seus pais ou responsáveis costumam: - Ler em casa.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Sempre ou quase sempre.
# Com que frequência seus pais ou responsáveis costumam: - Conversar com você sobre o que acontece na escola.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Sempre ou quase sempre.
# Com que frequência seus pais ou responsáveis costumam: - Incentivar você a estudar.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Sempre ou quase sempre.
# Com que frequência seus pais ou responsáveis costumam: - Incentivar você a fazer a tarefa de casa.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Sempre ou quase sempre.
# Com que frequência seus pais ou responsáveis costumam: - Incentivar você a comparecer às aulas.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Sempre ou quase sempre.
# Com que frequência seus pais ou responsáveis costumam: - Ir às reuniões de pais na escola.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Sempre ou quase sempre.
# Na rua em que você mora tem: - Asfalto ou calçamento.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na rua em que você mora tem: - Água tratada.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na rua em que você mora tem: - Iluminação.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Dos itens relacionados abaixo quantos existem na sua casa? - Geladeira.
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Tablet.
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Computador (ou notebook).
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Quartos para dormir.
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Televisão.
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Banheiro.
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Carro.
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Dos itens relacionados abaixo quantos existem na sua casa? - Celular com internet (smartphone).
# * - Nulo
# . - Branco
# A - Nenhum.
# B - 1.
# C - 2.
# D - 3 ou mais.
# Na sua casa tem: - Tv por internet (Netflix GloboPlay etc.).
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Rede Wi-Fi.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Um quarto só seu.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Mesa para estudar.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Forno de microondas.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Aspirador de pó.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Máquina de lavar roupa.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Freezer (independente ou segunda porta da geladeira).
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Na sua casa tem: - Garagem.
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Quanto tempo você demora para chegar à sua escola?
# * - Nulo
# . - Branco
# A - Menos de 30 minutos.
# B - Entre 30 minutos e uma hora.
# C - Mais de uma hora.
# Considerando a maior distância percorrida normalmente de que forma você chega à sua escola?
# * - Nulo
# . - Branco
# A - À pé.
# B - De bicicleta.
# C - De Van (ou Kombi).
# D - De ônibus.
# E - De metrô (ou trem urbano).
# F - De carro.
# G - Outros meios de transporte (barco, motocicleta, etc.)
# Você se utiliza de transporte escolar ou passe escolar para ir à escola?
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Com que idade você entrou na escola?
# * - Nulo
# . - Branco
# A - 3 anos ou menos.
# B - 4 ou 5 anos.
# C - 6 ou 7 anos.
# D - 8 anos ou mais.
# A partir do primeiro ano do ensino fundamental em que tipo de escola você estudou?
# * - Nulo
# . - Branco
# A - Somente em escola pública.
# B - Somente em escola particular.
# C - Em escola pública e em escola particular.
# Você já foi reprovado(a)?
# * - Nulo
# . - Branco
# A - Não.
# B - Sim, uma vez.
# C - Sim, duas vezes ou mais.
# Alguma vez você abandonou a escola deixando de frequentá-la até o final do ano escolar?
# * - Nulo
# . - Branco
# A - Nunca.
# B - Sim, uma vez.
# C - Sim, duas vezes ou mais.
# Fora da escola em dias de aula quanto tempo você usa para: - Estudar (lição de casa trabalhos escolares etc.).
# * - Nulo
# . - Branco
# A - Não uso meu tempo para isso.
# B - Menos de 1 hora.
# C - Entre 1 e 2 horas.
# D - Mais de 2 horas.
# Fora da escola em dias de aula quanto tempo você usa para: - Fazer cursos.
# * - Nulo
# . - Branco
# A - Não uso meu tempo para isso.
# B - Menos de 1 hora.
# C - Entre 1 e 2 horas.
# D - Mais de 2 horas.
# Fora da escola em dias de aula quanto tempo você usa para: - Trabalhar em casa (lavar louça limpar quintal cuidar dos irmãos).
# * - Nulo
# . - Branco
# A - Não uso meu tempo para isso.
# B - Menos de 1 hora.
# C - Entre 1 e 2 horas.
# D - Mais de 2 horas.
# Fora da escola em dias de aula quanto tempo você usa para: - Trabalhar fora de casa (recebendo ou não um salário).
# * - Nulo
# . - Branco
# A - Não uso meu tempo para isso.
# B - Menos de 1 hora.
# C - Entre 1 e 2 horas.
# D - Mais de 2 horas.
# Fora da escola em dias de aula quanto tempo você usa para: - Lazer (TV internet brincar música etc.).
# * - Nulo
# . - Branco
# A - Não uso meu tempo para isso.
# B - Menos de 1 hora.
# C - Entre 1 e 2 horas.
# D - Mais de 2 horas.
# Quando terminar o Ensino Médio você pretende:
# * - Nulo
# . - Branco
# A - Somente continuar estudando.
# B - Somente trabalhar.
# C - Continuar estudando e trabalhar.
# D - Ainda não sei.
# Você concluiu o Ensino Fundamental na Educação de Jovens e Adultos (EJA) antigo supletivo?
# * - Nulo
# . - Branco
# A - Não.
# B - Sim.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Eu possuía equipamento adequado para acompanhar o ensino remoto.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Eu tive conexão de internet adequada para acesso às aulas remotas.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Tive facilidade em usar os programas de comunicação nas aulas remotas.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Recebi material impresso da escola (livros apostilas atividades em folha etc.).
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Os professores me auxiliaram a entender o conteúdo.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Eu compreendi o conteúdo das aulas remotas.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Em casa havia um lugar tranquilo para eu assistir às aulas.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Meus familiares apoiaram o meu estudo.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
# Durante a pandemia indique a frequência com que os seguintes fatos ocorreram: - Meus colegas me apoiaram durante o ensino remoto.
# * - Nulo
# . - Branco
# A - Nunca ou quase nunca.
# B - De vez em quando.
# C - Várias vezes
# D - Sempre.
